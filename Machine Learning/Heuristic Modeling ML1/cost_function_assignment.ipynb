# %% [markdown]
# ## Heuristic Models (Cost Function Extension)
# Look at the Seattle weather in the data folder. Come up with a heuristic model to predict if it will rain today. Keep in mind this is a time series, which means that you only know what happened historically (before a given date).

# %% [markdown]
# ### The model :
#
# **It will rain tomorrow if it rained more than 0.7 inch (>0.7 PRCP) today.**

# %%
# here is an example of how to build and populate a hurestic model

import pandas as pd

df = pd.read_csv('https://raw.githubusercontent.com/daniel-dc-cd/data_science/master/module_4_ML/data/seattle_weather_1948-2017.csv')

numrows = 25549 # can be as large as 25549

#create an empty dataframe to hold 100 values
heuristic_df = pd.DataFrame({'yesterday':[0.0]*numrows,
                             'today':[0.0]*numrows,
                             'tomorrow':[0.0]*numrows,
                             'guess':[False]*numrows,  # logical guess
                             'rain_tomorrow':[False]*numrows,  # historical observation
                             'correct':[False]*numrows,  # TRUE if your guess matches the historical observation
                             'true_positive':[False]*numrows,  # TRUE If you said it would rain and it did
                             'false_positive':[False]*numrows,  # TRUE If you sait id would rain and it didn't
                             'true_negative':[False]*numrows,  # TRUE if you said it wouldn't rain and it didn't
                             'false_negative':[False]*numrows})  # TRUE if you said it wouldn't raing and it did

# sort columns for convience
seq = ['yesterday',
       'today',
       'tomorrow',
       'guess',
       'rain_tomorrow',
       'correct',
       'true_positive',
       'false_positive',
       'true_negative',
       'false_negative']

heuristic_df = heuristic_df.reindex(columns=seq)

# %%
df.head()
# Out:
#          DATE  PRCP  TMAX  TMIN  RAIN
# 0  1948-01-01  0.47    51    42  True
# 1  1948-01-02  0.59    45    36  True
# 2  1948-01-03  0.42    45    35  True
# 3  1948-01-04  0.31    45    34  True
# 4  1948-01-05  0.17    45    32  True

# %%
heuristic_df.head()
# Out:
#    yesterday  today  tomorrow  guess  rain_tomorrow  correct  true_positive  \
# 0        0.0    0.0       0.0  False          False    False          False
# 1        0.0    0.0       0.0  False          False    False          False
# 2        0.0    0.0       0.0  False          False    False          False
# 3        0.0    0.0       0.0  False          False    False          False
# 4        0.0    0.0       0.0  False          False    False          False
#
#    false_positive  true_negative  false_negative
# 0           False          False           False
# 1           False          False           False
# 2           False          False           False
# 3           False          False           False
# 4           False          False           False

# %%
# here is an example loop that populates the dataframe created earlier
# with the total percip from yesterday and today
# then the guess is set to true if rained both yesterday and today 

for _ in range(numrows):
    
    # start at time 2 in the data frame
    i = _ + 2
    
    # pull values from the dataframe
    yesterday = df.iloc[(i - 2), 1]
    today = df.iloc[(i - 1), 1]
    tomorrow = df.iloc[i, 1]
    rain_tomorrow = df.iloc[(i), 1]
    


   
    heuristic_df.iat[_, 0] = yesterday
    heuristic_df.iat[_, 1] = today
    heuristic_df.iat[_, 2] = tomorrow
    heuristic_df.iat[_, 3] = False # set guess default to False
    heuristic_df.iat[_, 4] = rain_tomorrow
    
      # example hueristic
    
    #today > 0.0 and yesterday > 0.0 
    #It will rain tomorrow if it rained more than 1 inch (>1.0 PRCP) today.
    
    if today > 0.7 : 
        heuristic_df.iat[_, 3] = True
        
    if heuristic_df.iat[_, 3] == heuristic_df.iat[_, 4]:
        heuristic_df.iat[_, 5] = True     #correct
        
        if heuristic_df.iat[_, 3] == True:
            heuristic_df.iat[_, 6] = True  # true positive
        else:
            heuristic_df.iat[_, 8] = True  # true negative
        
    else:
        heuristic_df.iat[_, 5] = False
        
        if heuristic_df.iat[_, 3] == True:
            heuristic_df.iat[_, 7] = True  # false positive
        else:
            heuristic_df.iat[_, 9] = True  # false negative

        



heuristic_df
# Out:
#        yesterday  today  tomorrow  guess  rain_tomorrow  correct  \
# 0           0.47   0.59      0.42  False           True    False
# 1           0.59   0.42      0.31  False           True    False
# 2           0.42   0.31      0.17  False           True    False
# 3           0.31   0.17      0.44  False           True    False
# 4           0.17   0.44      0.41  False           True    False
# 5           0.44   0.41      0.04  False           True    False
# 6           0.41   0.04      0.12  False           True    False
# 7           0.04   0.12      0.74  False           True    False
# 8           0.12   0.74      0.01   True           True     True
# 9           0.74   0.01      0.00  False          False     True
# 10          0.01   0.00      0.00  False          False     True
# 11          0.00   0.00      0.00  False          False     True
# 12          0.00   0.00      0.00  False          False     True
# 13          0.00   0.00      0.00  False          False     True
# 14          0.00   0.00      0.00  False          False     True
# 15          0.00   0.00      0.00  False          False     True
# 16          0.00   0.00      0.00  False          False     True
# 17          0.00   0.00      0.00  False          False     True
# 18          0.00   0.00      0.00  False          False     True
# 19          0.00   0.00      0.21  False           True    False
# 20          0.00   0.21      0.00  False          False     True
# 21          0.21   0.00      0.10  False           True    False
# 22          0.00   0.10      0.00  False          False     True
# 23          0.10   0.00      0.00  False          False     True
# 24          0.00   0.00      0.00  False          False     True
# 25          0.00   0.00      0.00  False          False     True
# 26          0.00   0.00      0.22  False           True    False
# 27          0.00   0.22      0.03  False           True    False
# 28          0.22   0.03      0.21  False           True    False
# 29          0.03   0.21      0.03  False           True    False
# ...          ...    ...       ...    ...            ...      ...
# 25519       0.81   0.05      0.46  False           True    False
# 25520       0.05   0.46      0.16  False           True    False
# 25521       0.46   0.16      0.00  False          False     True
# 25522       0.16   0.00      0.00  False          False     True
# 25523       0.00   0.00      0.58  False           True    False
# 25524       0.00   0.58      0.63  False           True    False
# 25525       0.58   0.63      1.14  False           True    False
# 25526       0.63   1.14      0.52   True           True     True
# 25527       1.14   0.52      0.20  False           True    False
# 25528       0.52   0.20      0.01  False           True    False
# 25529       0.20   0.01      0.19  False           True    False
# 25530       0.01   0.19      0.25  False           True    False
# 25531       0.19   0.25      0.00  False          False     True
# 25532       0.25   0.00      0.68  False           True    False
# 25533       0.00   0.68      0.00  False          False     True
# 25534       0.68   0.00      0.27  False           True    False
# 25535       0.00   0.27      0.27  False           True    False
# 25536       0.27   0.27      0.79  False           True    False
# 25537       0.27   0.79      0.05   True           True     True
# 25538       0.79   0.05      0.00  False          False     True
# 25539       0.05   0.00      0.00  False          False     True
# 25540       0.00   0.00      0.00  False          False     True
# 25541       0.00   0.00      0.00  False          False     True
# 25542       0.00   0.00      0.00  False          False     True
# 25543       0.00   0.00      0.00  False          False     True
# 25544       0.00   0.00      0.00  False          False     True
# 25545       0.00   0.00      0.00  False          False     True
# 25546       0.00   0.00      0.00  False          False     True
# 25547       0.00   0.00      0.00  False          False     True
# 25548       0.00   0.00      0.00  False          False     True
#
#        true_positive  false_positive  true_negative  false_negative
# 0              False           False          False            True
# 1              False           False          False            True
# 2              False           False          False            True
# 3              False           False          False            True
# 4              False           False          False            True
# 5              False           False          False            True
# 6              False           False          False            True
# 7               True           False          False            True
# 8               True           False          False            True
# 9              False           False           True           False
# 10             False           False           True           False
# 11             False           False           True           False
# 12             False           False           True           False
# 13             False           False           True           False
# 14             False           False           True           False
# 15             False           False           True           False
# 16             False           False           True           False
# 17             False           False           True           False
# 18             False           False           True           False
# 19             False           False          False            True
# 20             False           False           True           False
# 21             False           False          False            True
# 22             False           False           True           False
# 23             False           False           True           False
# 24             False           False           True           False
# 25             False           False           True           False
# 26             False           False          False            True
# 27             False           False          False            True
# 28             False           False          False            True
# 29             False           False          False            True
# ...              ...             ...            ...             ...
# 25519          False           False          False            True
# 25520          False           False          False            True
# 25521          False           False           True           False
# 25522          False           False           True           False
# 25523          False           False          False            True
# 25524           True           False          False            True
# 25525           True           False          False            True
# 25526           True           False          False            True
# 25527          False           False          False            True
# 25528          False           False          False            True
# 25529          False           False          False            True
# 25530          False           False          False            True
# 25531          False           False           True           False
# 25532          False           False          False            True
# 25533          False           False           True           False
# 25534          False           False          False            True
# 25535          False           False          False            True
# 25536           True           False          False            True
# 25537           True           False          False            True
# 25538          False           False           True           False
# 25539          False           False           True           False
# 25540          False           False           True           False
# 25541          False           False           True           False
# 25542          False           False           True           False
# 25543          False           False           True           False
# 25544          False           False           True           False
# 25545          False           False           True           False
# 25546          False           False           True           False
# 25547          False           False           True           False
# 25548          False           False           True           False
#
# [25549 rows x 10 columns]

# %%
from sklearn.model_selection import train_test_split 

# enter split function here to make h_train and h_test subsets of the data
X_train, X_test, y_train, y_test = train_test_split(df, df['RAIN'], test_size=0.3)

# %%
#The accuracy of predicitions 

heuristic_df['correct'].value_counts()/numrows
# Out:
# True     0.595287
# False    0.404713
# Name: correct, dtype: float64

# %%
#The precision of predicitions
# precision is the percent of your postive prediction which are correct

heuristic_df['true_positive'].sum() / (heuristic_df['true_positive'].sum() + heuristic_df['false_positive'].sum())
# Out:
# 0.911543287327478

# %%
#the recall of your predicitions

# recall the percent of the time you are correct when you predict positive

heuristic_df['true_positive'].sum() / (heuristic_df['true_positive'].sum() + heuristic_df['false_negative'].sum())
# Out:
# 0.1176708778749595

# %%
heuristic_df['false_negative'].sum()
# Out:
# 10895

# %%
#The sum of squared error (SSE) of your predictions

import numpy as np

def sse(y_true, y_pred):
    '''returns sum of squared errors (actual vs model)'''
    squared_errors = (y_true - y_pred) ** 2
    return np.sum(squared_errors)


sse(y_true=heuristic_df['rain_tomorrow'].astype('int'), y_pred=heuristic_df['guess'].astype('int'))
# Out:
# 10340

# %%
from sklearn.metrics import mean_squared_error

mean_squared_error(y_true=heuristic_df['rain_tomorrow'].astype('int'), y_pred=heuristic_df['guess'].astype('int'))
# Out:
# 0.40471251320991036
